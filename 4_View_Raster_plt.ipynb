# %% [markdown]
# # View Raster With matplot
#
# ### Import Modules

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import xarray as xr
import gdal #need if loading in from aws S3 bucket

# %% [markdown]
# ### Load Raster into xarray

# %%
raster1 = xr.open_rasterio('/opt/logan/docker/testPangeoJupyter/HLS.S30.T11SLU.2020314T183609.v1.5_EVI.tif')
raster2 = xr.open_rasterio('/opt/logan/docker/testPangeoJupyter/HLS.S30.T11SLU.2020274T183109.v1.5_EVI.tif')

# %% [markdown]
# ### Display raster

# %%
raster1.plot()

# %% [markdown]
# ### Display raster with value constraints and new cmap

# %%
raster2.plot(vmin=-1, vmax=1, cmap='RdYlGn')
